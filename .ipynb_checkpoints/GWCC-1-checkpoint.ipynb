# %% [markdown]
# ## Geographically Weighted Correlation Coefficient

# %% [markdown]
# ### Import relevant dependencies

# %%
import pandas as pd
import numpy as np
import geopandas as gp
import libpysal as ps
from mgwr.gwr import GWR, MGWR, GWRResults
from mgwr.sel_bw import Sel_BW

# %%
georgia_data = pd.read_csv(ps.examples.get_path('GData_utm.csv'))
georgia_shp = gp.read_file(ps.examples.get_path('G_utm.shp'))

# %% [markdown]
# #### Prepare the Georgia dataset inputs

# %%
g_y = georgia_data['PctBach'].values.reshape((-1,1))
g_X = georgia_data[['PctFB', 'PctBlack', 'PctRural']].values
u = georgia_data['X']
v = georgia_data['Y']


g_coords = list(zip(u,v))

# %%
georgia_data.head()
# Out:
#    AreaKey  Latitude  Longitud  TotPop90  PctRural  PctBach  PctEld  PctFB  \
# 0    13001  31.75339 -82.28558     15744      75.6      8.2   11.43   0.64
# 1    13003  31.29486 -82.87474      6213     100.0      6.4   11.77   1.58
# 2    13005  31.55678 -82.45115      9566      61.7      6.6   11.11   0.27
# 3    13007  31.33084 -84.45401      3615     100.0      9.4   13.17   0.11
# 4    13009  33.07193 -83.25085     39530      42.7     13.3    8.64   1.43
#
#    PctPov  PctBlack   ID         X          Y
# 0    19.9     20.76  133  941396.6  3521764.0
# 1    26.0     26.86  158  895553.0  3471916.0
# 2    24.1     15.42  146  930946.4  3502787.0
# 3    24.8     51.67  155  745398.6  3474765.0
# 4    17.5     42.39   79  849431.3  3665553.0

# %% [markdown]
# #### Standardization Routine

# %% [markdown]
# I commented out the standardization routine here, because I will be doing it inside the _compute_betas_gwr()_ function of the `iwls.py`

# %%
# g_X = (g_X - g_X.mean(axis=0)) / g_X.std(axis=0)

# # g_y = g_y.reshape((-1,1))

# g_y = (g_y - g_y.mean(axis=0)) / g_y.std(axis=0)

# %% [markdown]
# #### Calibrate GWR model

# %%
gwr_selector = Sel_BW(g_coords, g_y, g_X)
gwr_bw = gwr_selector.search()
print(gwr_bw)
gwr_results = GWR(g_coords, g_y, g_X, gwr_bw).fit()
# Out:
# c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\spglm\iwls.py:48: RuntimeWarning: invalid value encountered in true_divide
#   x_stdz = (x - x.mean(axis=0)) / x.std(axis=0) # standardize the design matrix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 gwr_selector = Sel_BW(g_coords, g_y, g_X)
# ----> 2 gwr_bw = gwr_selector.search()
#       3 print(gwr_bw)
#       4 gwr_results = GWR(g_coords, g_y, g_X, gwr_bw).fit()
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:319, in Sel_BW.search(self, search_method, criterion, bw_min, bw_max, interval, tol, max_iter, init_multi, tol_multi, rss_score, max_iter_multi, multi_bw_min, multi_bw_max, bws_same_times, pool, verbose)
#     316     self.bw_init = self.bw[
#     317         -1]  #scalar, optimal bw from initial gwr model
#     318 else:
# --> 319     self._bw()
#     320     self.sel_hist = self.bw[-1]
#     322 self.pool = None
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:337, in Sel_BW._bw(self)
#     334     a, c = self._init_section(self.X_glob, self.X_loc, self.coords,
#     335                               self.constant)
#     336     delta = 0.38197  #1 - (np.sqrt(5.0)-1.0)/2.0
# --> 337     self.bw = golden_section(a, c, delta, gwr_func, self.tol,
#     338                              self.max_iter, self.int_score,
#     339                              self.verbose)
#     340 elif self.search_method == 'interval':
#     341     self.bw = equal_interval(self.bw_min, self.bw_max, self.interval,
#     342                              gwr_func, self.int_score, self.verbose)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\search.py:62, in golden_section(a, c, delta, function, tol, max_iter, int_score, verbose)
#      60     score_b = dict[b]
#      61 else:
# ---> 62     score_b = function(b)
#      63     dict[b] = score_b
#      64     if verbose:
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:326, in Sel_BW._bw.<locals>.<lambda>(bw)
#     325 def _bw(self):
# --> 326     gwr_func = lambda bw: getDiag[self.criterion](GWR(
#     327         self.coords, self.y, self.X_loc, bw, family=self.family, kernel=
#     328         self.kernel, fixed=self.fixed, constant=self.constant, offset=self.
#     329         offset, spherical=self.spherical).fit(lite=True, pool=self.pool))
#     331     self._optimized_function = gwr_func
#     333     if self.search_method == 'golden_section':
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:337, in GWR.fit(self, ini_params, tol, max_iter, solve, lite, pool)
#     334 else:
#     335     rslt = map(self._local_fit, range(m))  #sequential
# --> 337 rslt_list = list(zip(*rslt))
#     338 influ = np.array(rslt_list[0]).reshape(-1, 1)
#     339 resid = np.array(rslt_list[1]).reshape(-1, 1)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:253, in GWR._local_fit(self, i)
#     248 wi = self._build_wi(i, self.bw).reshape(-1, 1)  #local spatial weights
#     252 if isinstance(self.family, Gaussian):
# --> 253     betas, inv_xtx_xt = _compute_betas_gwr(self.y, self.X, wi)
#     254     predy = np.dot(self.X[i], betas)[0]
#     255     resid = self.y[i] - predy
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\spglm\iwls.py:59, in _compute_betas_gwr(y, x, wi)
#      57 xT = (x_stdz * wi).T
#      58 xtx = np.dot(xT, x_stdz)
# ---> 59 xtx_inv_xt = linalg.solve(xtx, xT)
#      60 betas = np.dot(xtx_inv_xt, y)
#      61 return betas, xtx_inv_xt
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\scipy\linalg\basic.py:137, in solve(a, b, sym_pos, lower, overwrite_a, overwrite_b, debug, check_finite, assume_a, transposed)
#     134 # Flags for 1-D or N-D right-hand side
#     135 b_is_1D = False
# --> 137 a1 = atleast_2d(_asarray_validated(a, check_finite=check_finite))
#     138 b1 = atleast_1d(_asarray_validated(b, check_finite=check_finite))
#     139 n = a1.shape[0]
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\scipy\_lib\_util.py:293, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     291         raise ValueError('masked arrays are not supported')
#     292 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 293 a = toarray(a)
#     294 if not objects_ok:
#     295     if a.dtype is np.dtype('O'):
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\numpy\lib\function_base.py:603, in asarray_chkfinite(a, dtype, order)
#     601 a = asarray(a, dtype=dtype, order=order)
#     602 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 603     raise ValueError(
#     604         "array must not contain infs or NaNs")
#     605 return a
#
# ValueError: array must not contain infs or NaNs

# %%
gwr_selector = Sel_BW(g_coords, g_y, g_X)
gwr_bw = gwr_selector.search()
print(gwr_bw)
gwr_results = GWR(g_coords, g_y, g_X, gwr_bw).fit()
# Out:
# c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:337, in Sel_BW._bw(self)
#     334     a, c = self._init_section(self.X_glob, self.X_loc, self.coords,
#     335                               self.constant)
#     336     delta = 0.38197  #1 - (np.sqrt(5.0)-1.0)/2.0
# --> 337     self.bw = golden_section(a, c, delta, gwr_func, self.tol,
#     338                              self.max_iter, self.int_score,
#     339                              self.verbose)
#     340 elif self.search_method == 'interval':
#     341     self.bw = equal_interval(self.bw_min, self.bw_max, self.interval,
#     342                              gwr_func, self.int_score, self.verbose)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\search.py:62, in golden_section(a, c, delta, function, tol, max_iter, int_score, verbose)
#      60     score_b = dict[b]
#      61 else:
# ---> 62     score_b = function(b)
#      63     dict[b] = score_b
#      64     if verbose:
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:326, in Sel_BW._bw.<locals>.<lambda>(bw)
#     325 def _bw(self):
# --> 326     gwr_func = lambda bw: getDiag[self.criterion](GWR(
#     327         self.coords, self.y, self.X_loc, bw, family=self.family, kernel=
#     328         self.kernel, fixed=self.fixed, constant=self.constant, offset=self.
#     329         offset, spherical=self.spherical).fit(lite=True, pool=self.pool))
#     331     self._optimized_function = gwr_func
#     333     if self.search_method == 'golden_section':
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:337, in GWR.fit(self, ini_params, tol, max_iter, solve, lite, pool)
#     334 else:
#     335     rslt = map(self._local_fit, range(m))  #sequential
# --> 337 rslt_list = list(zip(*rslt))
#     338 influ = np.array(rslt_list[0]).reshape(-1, 1)
#     339 resid = np.array(rslt_list[1]).reshape(-1, 1)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:253, in GWR._local_fit(self, i)
#     248 wi = self._build_wi(i, self.bw).reshape(-1, 1)  #local spatial weights
#     252 if isinstance(self.family, Gaussian):
# --> 253     betas, inv_xtx_xt = _compute_betas_gwr(self.y, self.X, wi)
#     254     predy = np.dot(self.X[i], betas)[0]
#     255     resid = self.y[i] - predy
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
gwr_selector = Sel_BW(g_coords, g_y, g_X)
gwr_bw = gwr_selector.search()
print(gwr_bw)
gwr_results = GWR(g_coords, g_y, g_X, gwr_bw).fit()
# Out:
# [[1.000e+00 6.400e-01 2.076e+01 7.560e+01]
#  [1.000e+00 1.580e+00 2.686e+01 1.000e+02]
#  [1.000e+00 2.700e-01 1.542e+01 6.170e+01]
#  [1.000e+00 1.100e-01 5.167e+01 1.000e+02]
#  [1.000e+00 1.430e+00 4.239e+01 4.270e+01]
#  [1.000e+00 3.400e-01 3.490e+00 1.000e+02]
#  [1.000e+00 9.200e-01 1.144e+01 6.460e+01]
#  [1.000e+00 8.200e-01 9.210e+00 7.520e+01]
#  [1.000e+00 3.300e-01 3.133e+01 4.700e+01]
#  [1.000e+00 1.190e+00 1.162e+01 6.620e+01]
#  [1.000e+00 1.060e+00 4.168e+01 1.610e+01]
#  [1.000e+00 6.400e-01 2.236e+01 5.790e+01]
#  [1.000e+00 3.300e-01 4.580e+00 1.000e+02]
#  [1.000e+00 1.760e+00 4.147e+01 6.560e+01]
]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 gwr_selector = Sel_BW(g_coords, g_y, g_X)
# ----> 2 gwr_bw = gwr_selector.search()
#       3 print(gwr_bw)
#       4 gwr_results = GWR(g_coords, g_y, g_X, gwr_bw).fit()
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:319, in Sel_BW.search(self, search_method, criterion, bw_min, bw_max, interval, tol, max_iter, init_multi, tol_multi, rss_score, max_iter_multi, multi_bw_min, multi_bw_max, bws_same_times, pool, verbose)
#     316     self.bw_init = self.bw[
#     317         -1]  #scalar, optimal bw from initial gwr model
#     318 else:
# --> 319     self._bw()
#     320     self.sel_hist = self.bw[-1]
#     322 self.pool = None
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:337, in Sel_BW._bw(self)
#     334     a, c = self._init_section(self.X_glob, self.X_loc, self.coords,
#     335                               self.constant)
#     336     delta = 0.38197  #1 - (np.sqrt(5.0)-1.0)/2.0
# --> 337     self.bw = golden_section(a, c, delta, gwr_func, self.tol,
#     338                              self.max_iter, self.int_score,
#     339                              self.verbose)
#     340 elif self.search_method == 'interval':
#     341     self.bw = equal_interval(self.bw_min, self.bw_max, self.interval,
#     342                              gwr_func, self.int_score, self.verbose)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\search.py:62, in golden_section(a, c, delta, function, tol, max_iter, int_score, verbose)
#      60     score_b = dict[b]
#      61 else:
# ---> 62     score_b = function(b)
#      63     dict[b] = score_b
#      64     if verbose:
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:326, in Sel_BW._bw.<locals>.<lambda>(bw)
#     325 def _bw(self):
# --> 326     gwr_func = lambda bw: getDiag[self.criterion](GWR(
#     327         self.coords, self.y, self.X_loc, bw, family=self.family, kernel=
#     328         self.kernel, fixed=self.fixed, constant=self.constant, offset=self.
#     329         offset, spherical=self.spherical).fit(lite=True, pool=self.pool))
#     331     self._optimized_function = gwr_func
#     333     if self.search_method == 'golden_section':
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:337, in GWR.fit(self, ini_params, tol, max_iter, solve, lite, pool)
#     334 else:
#     335     rslt = map(self._local_fit, range(m))  #sequential
# --> 337 rslt_list = list(zip(*rslt))
#     338 influ = np.array(rslt_list[0]).reshape(-1, 1)
#     339 resid = np.array(rslt_list[1]).reshape(-1, 1)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:253, in GWR._local_fit(self, i)
#     248 wi = self._build_wi(i, self.bw).reshape(-1, 1)  #local spatial weights
#     252 if isinstance(self.family, Gaussian):
# --> 253     betas, inv_xtx_xt = _compute_betas_gwr(self.y, self.X, wi)
#     254     predy = np.dot(self.X[i], betas)[0]
#     255     resid = self.y[i] - predy
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
#  [ 0.00000000e+00 -1.14518017e-01  1.52180745e-01 -9.69121709e-01]
#  [ 0.00000000e+00 -6.33829666e-01  7.65654949e-01 -9.50612803e-01]
#  [ 0.00000000e+00 -7.39314845e-01  1.06979503e+00  1.10387586e+00]
#  [ 0.00000000e+00 -2.03774707e-01 -1.57512715e+00  1.10387586e+00]
#  [ 0.00000000e+00 -4.55316287e-01  2.23296669e-02 -1.80642275e-01]
#  [ 0.00000000e+00 -5.77029954e-01 -1.36563408e+00 -9.39507458e-01]
#  [ 0.00000000e+00 -3.90402330e-01 -5.20736397e-01 -3.32415312e-01]
#  [ 0.00000000e+00 -4.14745064e-01 -8.73223546e-02 -5.91540008e-01]
#  [ 0.00000000e+00 -5.20230243e-01  1.89507077e+00  1.10387586e+00]
#  [ 0.00000000e+00 -7.55543334e-01  1.41202476e+00 -1.14010210e-01]
#  [ 0.00000000e+00 -5.12115998e-01 -4.58407880e-01 -3.80538470e-01]
#  [ 0.00000000e+00 -8.44800023e-01  1.31622352e+00  1.10387586e+00]
#  [ 0.00000000e+00 -6.33829666e-01  1.53912093e-01  1.10387586e+00]
#  [ 0.00000000e+00  3.96526289e-02 -1.43142529e+00  1.10387586e+00]
#  [ 0.00000000e+00  1.15130413e+00 -1.34658925e+00 -6.65855016e-03]
#  [ 0.00000000e+00 -8.44800023e-01  2.52021796e-01  1.10387586e+00]
#  [ 0.00000000e+00 -5.68915710e-01  1.07037215e+00 -3.91643814e-01]
#  [ 0.00000000e+00 -6.82515133e-01  8.42411364e-01  1.10387586e+00]
#  [ 0.00000000e+00 -4.39087798e-01  1.91424626e-01  3.40610450e-02]]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 2>()
#       1 gwr_selector = Sel_BW(g_coords, g_y, g_X)
# ----> 2 gwr_bw = gwr_selector.search()
#       3 print(gwr_bw)
#       4 gwr_results = GWR(g_coords, g_y, g_X, gwr_bw).fit()
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:319, in Sel_BW.search(self, search_method, criterion, bw_min, bw_max, interval, tol, max_iter, init_multi, tol_multi, rss_score, max_iter_multi, multi_bw_min, multi_bw_max, bws_same_times, pool, verbose)
#     316     self.bw_init = self.bw[
#     317         -1]  #scalar, optimal bw from initial gwr model
#     318 else:
# --> 319     self._bw()
#     320     self.sel_hist = self.bw[-1]
#     322 self.pool = None
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:337, in Sel_BW._bw(self)
#     334     a, c = self._init_section(self.X_glob, self.X_loc, self.coords,
#     335                               self.constant)
#     336     delta = 0.38197  #1 - (np.sqrt(5.0)-1.0)/2.0
# --> 337     self.bw = golden_section(a, c, delta, gwr_func, self.tol,
#     338                              self.max_iter, self.int_score,
#     339                              self.verbose)
#     340 elif self.search_method == 'interval':
#     341     self.bw = equal_interval(self.bw_min, self.bw_max, self.interval,
#     342                              gwr_func, self.int_score, self.verbose)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\search.py:62, in golden_section(a, c, delta, function, tol, max_iter, int_score, verbose)
#      60     score_b = dict[b]
#      61 else:
# ---> 62     score_b = function(b)
#      63     dict[b] = score_b
#      64     if verbose:
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\sel_bw.py:326, in Sel_BW._bw.<locals>.<lambda>(bw)
#     325 def _bw(self):
# --> 326     gwr_func = lambda bw: getDiag[self.criterion](GWR(
#     327         self.coords, self.y, self.X_loc, bw, family=self.family, kernel=
#     328         self.kernel, fixed=self.fixed, constant=self.constant, offset=self.
#     329         offset, spherical=self.spherical).fit(lite=True, pool=self.pool))
#     331     self._optimized_function = gwr_func
#     333     if self.search_method == 'golden_section':
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:337, in GWR.fit(self, ini_params, tol, max_iter, solve, lite, pool)
#     334 else:
#     335     rslt = map(self._local_fit, range(m))  #sequential
# --> 337 rslt_list = list(zip(*rslt))
#     338 influ = np.array(rslt_list[0]).reshape(-1, 1)
#     339 resid = np.array(rslt_list[1]).reshape(-1, 1)
#
# File c:\Users\Lenovo\anaconda3\envs\standardweight\lib\site-packages\mgwr\gwr.py:253, in GWR._local_fit(self, i)
#     248 wi = self._build_wi(i, self.bw).reshape(-1, 1)  #local spatial weights
#     252 if isinstance(self.family, Gaussian):
# --> 253     betas, inv_xtx_xt = _compute_betas_gwr(self.y, self.X, wi)
#     254     predy = np.dot(self.X[i], betas)[0]
#     255     resid = self.y[i] - predy
#
# TypeError: cannot unpack non-iterable NoneType object

# %%
gwr_results.summary()

# %%
# from sklearn.preprocessing import StandardScaler

# %%
# np.mean(gwr_results.params[:, 0])
# # gwr_results.influ

# %% [markdown]
# ### Generate pearson's correlation coefficient

# %%
# res = GWRResults(gwr_results.model, gwr_results.params, gwr_results.predy, gwr_results.S, gwr_results.CCT, gwr_results.influ )

# a,s,d,f=res.local_collinearity()

# # res.local_collinearity()

# gwr_results.local_collinearity()
# np.mean(res.localR2)

# res.local_collinearity()

# %%
a,s,d,f = gwr_results.local_collinearity()

# %%
a[:, 0].mean(), a[:, 1].mean(), a[:, 2].mean()
# Out:
# (-0.15138960939787022, -0.5797078107906775, -0.004704691983920316)

# %% [markdown]
# #### Global correlation coefficient

# %%
from scipy.stats import pearsonr

corr, u = pearsonr(g_X[:,0], g_y.flatten())

print(f'{corr:.2f}') # to 2 d.p
# Out:
# 0.67

# %% [markdown]
#  The cell below has my implementation of the _compute_betas_gwr()_ function from inside the conda environment `spglm/iwls.py` source code.  <br /> <br /> But when I do this and run the jupyter notebook cells I get the above error.

# %%
def _compute_betas_gwr(y, x, wi):
    """
    compute MLE coefficients using iwls routine

    Methods: p189, Iteratively (Re)weighted Least Squares (IWLS),
    Fotheringham, A. S., Brunsdon, C., & Charlton, M. (2002).
    Geographically weighted regression: the analysis of spatially varying relationships.
    """

    xw = (x * wi)  # weight before standardization -> result is the weighted design matrix

    x_stdz = (x - x.mean(axis=0)) / x.std(axis=0) # standardize the design matrix 

    xw_stdz = (xw - xw.mean(axis=0)) / xw.std(axis=0)  # standardize the weighted design matrix

    y = (y - y.mean(axis=0)) / y.std(axis=0)  # standardize the dependent variable --> Making sure x and y are standardized


    xT = xw_stdz.T
    xtx = np.dot(xT, x_stdz)
    xtx_inv_xt = linalg.solve(xtx, xT)
    betas = np.dot(xtx_inv_xt, y)
    return betas, xtx_inv_xt
